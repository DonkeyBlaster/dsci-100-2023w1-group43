# %%
# Load libraries, run before everything else
library(tidyverse)
library(repr)
library(tidymodels)
install.packages("kknn")
install.packages("con2aqi")
library(con2aqi)
library(zoo) # for moving averages
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# Get weather + pollution data for the Aotizhongxin station in Beijing
download.file("https://raw.githubusercontent.com/DonkeyBlaster/dsci-100-2023w1-group43/main/PRSA_Data_Aotizhongxin_20130301-20170228.csv", "Aotizhongxin_data.csv")
air_quality_data <- read_csv("Aotizhongxin_data.csv") |>
    select(-station) |> # This just says "Aotizhongxin", no need to keep it around
    select(-No)  # This is a continuously increasing counter, we don't need it either
head(air_quality_data, 3)
tail(air_quality_data, 3)
# Out:
# Rows: 35064 Columns: 18
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): wd, station
# dbl (16): No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, P...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   year month day hour PM2.5 PM10 SO2 NO2 CO  O3 TEMP PRES   DEWP  RAIN wd  WSPM
# 1 2013 3     1   0    4     4    4    7  300 77 -0.7 1023.0 -18.8 0    NNW 4.4
# 2 2013 3     1   1    8     8    4    7  300 77 -1.1 1023.2 -18.2 0    N   4.7
# 3 2013 3     1   2    7     7    5   10  300 73 -1.1 1023.5 -18.2 0    NNW 5.6
#   year month day hour PM2.5 PM10 SO2 NO2 CO  O3 TEMP PRES   DEWP  RAIN wd  WSPM
# 1 2017 2     28  21   16    37   10  66  700 58 10.8 1014.2 -13.3 0    NW  1.1
# 2 2017 2     28  22   21    44   12  87  700 35 10.5 1014.4 -12.9 0    NNW 1.2
# 3 2017 2     28  23   19    31   10  79  600 42  8.6 1014.1 -15.9 0    NNE 1.3

# %%
air_quality_data <- air_quality_data |> na.omit() # AQI cannot be calculated with NA values

# %%
R = 0.082057366080960  # Gas constant for litres, atmospheres, kelvin, mols.
SO2_molecular_weight = 64.07  # g/mol
NO2_molecular_weight = 46.01  # g/mol
CO_molecular_weight = 28.01  # g/mol
O3_molecular_weight = 48.00  # g/mol
air_quality_data <- air_quality_data |>
    # PV = nRT formula rearranged to V = RT/P, n=1.
    mutate(volume = R * (273.2 + TEMP) / (PRES/1013)) |>   # Convert temp to Kelvin, pressure to atmospheres
    mutate(so2_ppb = volume * SO2 / SO2_molecular_weight) |>
    mutate(no2_ppb = volume * NO2 / NO2_molecular_weight) |>
    # Multiply by div by 1000 for ppb -> ppm
    mutate(co_ppm = volume * CO / CO_molecular_weight / 1000) |>
    mutate(o3_ppm = volume * O3 / O3_molecular_weight / 1000)
head(air_quality_data, 3)
tail(air_quality_data, 3)
# Out:
#   year month day hour PM2.5 PM10 SO2 NO2 CO  O3 ⋯ PRES   DEWP  RAIN wd  WSPM
# 1 2013 3     1   0    4     4    4    7  300 77 ⋯ 1023.0 -18.8 0    NNW 4.4
# 2 2013 3     1   1    8     8    4    7  300 77 ⋯ 1023.2 -18.2 0    N   4.7
# 3 2013 3     1   2    7     7    5   10  300 73 ⋯ 1023.5 -18.2 0    NNW 5.6
#   volume   so2_ppb  no2_ppb  co_ppm    o3_ppm
# 1 22.14205 1.382366 3.368711 0.2371516 0.03551954
# 2 22.10523 1.380067 3.363108 0.2367572 0.03546047
# 3 22.09875 1.724579 4.803032 0.2366878 0.03360852
#   year month day hour PM2.5 PM10 SO2 NO2 CO  O3 ⋯ PRES   DEWP  RAIN wd  WSPM
# 1 2017 2     28  21   16    37   10  66  700 58 ⋯ 1014.2 -13.3 0    NW  1.1
# 2 2017 2     28  22   21    44   12  87  700 35 ⋯ 1014.4 -12.9 0    NNW 1.2
# 3 2017 2     28  23   19    31   10  79  600 42 ⋯ 1014.1 -15.9 0    NNE 1.3
#   volume   so2_ppb  no2_ppb  co_ppm    o3_ppm
# 1 23.27672 3.633014 33.38977 0.5817102 0.02812603
# 2 23.24755 4.354152 43.95863 0.5809812 0.01695134
# 3 23.09868 3.605226 39.66086 0.4947951 0.02021135

# %%
air_quality_data <- air_quality_data |>
    mutate(pm2.5_24hour = zoo::rollmean(PM2.5, k = 24, fill = NA, align = "right")) |>
    mutate(pm10_24hour = zoo::rollmean(PM10, k = 24, fill = NA, align = "right")) |>
    mutate(co_8hour = zoo::rollmean(co_ppm, k = 8, fill = NA, align = "right")) |>
    mutate(o3_8hour = zoo::rollmean(o3_ppm, k = 8, fill = NA, align = "right"))  # For o3 specifically, con2aqi allows us to choose 1 or 8 hours.
    # We're using 8 hours as the 1-hour window does not allow for reporting of AQI values less than 101.
head(air_quality_data, 26)
# Out:
#    year month day hour PM2.5 PM10 SO2 NO2 CO  O3 ⋯ WSPM volume   so2_ppb
# 1  2013 3     1    0    4     4    4   7  300 77 ⋯ 4.4  22.14205 1.382366
# 2  2013 3     1    1    8     8    4   7  300 77 ⋯ 4.7  22.10523 1.380067
# 3  2013 3     1    2    7     7    5  10  300 73 ⋯ 5.6  22.09875 1.724579
# 4  2013 3     1    3    6     6   11  11  300 72 ⋯ 3.1  22.05284 3.786191
# 5  2013 3     1    4    3     3   12  12  300 72 ⋯ 2.0  21.98913 4.118458
# 6  2013 3     1    5    5     5   18  18  400 66 ⋯ 3.7  21.96435 6.170723
# 7  2013 3     1    6    3     3   18  32  500 50 ⋯ 2.5  21.91270 6.156213
# 8  2013 3     1    7    3     6   19  41  500 43 ⋯ 3.8  21.97441 6.516526
# 9  2013 3     1    8    3     6   16  43  500 45 ⋯ 4.1  22.09260 5.517115
# 10 2013 3     1    9    3     8   12  28  400 59 ⋯ 2.6  22.17721 4.153683
# 11 2013 3     1   10    3     6    9  12  400 72 ⋯ 3.6  22.24027 3.124121
# 12 2013 3     1   11    3     6    9  14  400 71 ⋯ 3.7  22.32111 3.135477
# 13 2013 3     1   12    3     6    7  13  300 74 ⋯ 5.1  22.42158 2.449681
# 14 2013 3     1   13    3     6    7  12  400 76 ⋯ 4.3  22.55902 2.464697
# 15 2013 3     1   14    6     9    7  11  400 77 ⋯ 4.4  22.62233 2.471614
# 16 2013 3     1   15    8    15    7  14  400 76 ⋯ 2.8  22.64295 2.473867
# 17 2013 3     1   16    9    19    9  13  400 76 ⋯ 3.9  22.62085 3.177581
# 18 2013 3     1   17   10    23   11  15  400 74 ⋯ 2.8  22.47583 3.858812
# 19 2013 3     1   18   11    20    8  20  500 70 ⋯ 2.1  22.35467 2.791281
# 20 2013 3     1   19    8    14   12  30  500 60 ⋯ 2.8  22.27044 4.171145
# 21 2013 3     1   20   11    17   13  33  600 55 ⋯ 2.1  22.20466 4.505394
# 22 2013 3     1   21   12    18   16  35  500 50 ⋯ 0.8  22.09434 5.517551
# 23 2013 3     1   22   15    19   21  57  700 32 ⋯ 1.8  22.10997 7.246906
# 24 2013 3     1   23   24    24   26  54  600 36 ⋯ 1.4  22.02123 8.936353
# 25 2013 3     2    0   22    24   24  44  500 44 ⋯ 1.4  21.99443 8.238900
# 26 2013 3     2    1   14    17   21  36  400 50 ⋯ 1.1  21.93967 7.191089
#    no2_ppb   co_ppm    o3_ppm     pm2.5_24hour pm10_24hour co_8hour  o3_8hour
# 1   3.368711 0.2371516 0.03551954    NA              NA           NA         NA
# 2   3.363108 0.2367572 0.03546047    NA              NA           NA         NA
# 3   4.803032 0.2366878 0.03360852    NA              NA           NA         NA
# 4   5.272359 0.2361961 0.03307926    NA              NA           NA         NA
# 5   5.735049 0.2355137 0.03298370    NA              NA           NA         NA
# 6   8.592876 0.3136644 0.03020098    NA              NA           NA         NA
# 7  15.240303 0.3911585 0.02282573    NA              NA           NA         NA
# 8  19.581630 0.3922601 0.01968541    NA              NA    0.2849237 0.03042045
# 9  20.647289 0.3943699 0.02071181    NA              NA    0.3045759 0.02856948
# 10 13.496235 0.3167041 0.02725948    NA              NA    0.3145693 0.02754436
# 11  5.800548 0.3176047 0.03336040    NA              NA    0.3246839 0.02751335
# 12  6.791905 0.3187592 0.03301664    NA              NA    0.3350043 0.02750552
# 13  6.335157 0.2401455 0.03456661    NA              NA    0.3355833 0.02770338
# 14  5.883682 0.3221566 0.03571845    NA              NA    0.3366448 0.02839307
# 15  5.408513 0.3230608 0.03628999    NA              NA    0.3281326 0.03007610
# 16  6.889836 0.3233553 0.03585134    NA              NA    0.3195195 0.03209684
# 17  6.391458 0.3230396 0.03581634    NA              NA    0.3106032 0.03398491
# 18  7.327481 0.3209686 0.03465023    NA              NA    0.3111363 0.03490875
# 19  9.717311 0.3990481 0.03260057    NA              NA    0.3213167 0.03481377
# 20 14.521043 0.3975444 0.02783805    NA              NA    0.3311649 0.03416645
# 21 15.925970 0.4756443 0.02544284    NA              NA    0.3606022 0.03302598
# 22 16.807259 0.3944010 0.02301494    NA              NA    0.3696328 0.03143804
# 23 27.391176 0.5525518 0.01473998    NA              NA    0.3983191 0.02874429
# 24 25.845396 0.4717151 0.01651593 7.125        10.75000    0.4168641 0.02632736
# 25 21.033578 0.3926175 0.02016156 7.875        11.58333    0.4255614 0.02437051
# 26 17.166446 0.3133120 0.02285382 8.125        11.95833    0.4246043 0.02289596

# %%
# This cell takes a while.
air_quality_data <- air_quality_data |>
    na.omit() |>  #  We will remove all rows with NA first.
    mutate(pm2.5_aqi = con2aqi(pollutant = "pm25", con = pm2.5_24hour)) |>
    mutate(pm10_aqi = con2aqi(pollutant = "pm10", con = pm10_24hour)) |>
    mutate(so2_aqi = con2aqi(pollutant = "so2", con = so2_ppb)) |>
    mutate(no2_aqi = con2aqi(pollutant = "no2", con = no2_ppb)) |>
    mutate(co_aqi = con2aqi(pollutant = "co", con = co_8hour)) |>
    mutate(o3_aqi = con2aqi(pollutant = "o3", con = o3_8hour, type = "8h"))
air_quality_data
# Out:
#       year month day hour PM2.5 PM10 SO2 NO2 CO   O3  ⋯ pm2.5_24hour
# 1     2013 3     1   23    24    24  26   54  600 36  ⋯  7.125000
# 2     2013 3     2    0    22    24  24   44  500 44  ⋯  7.875000
# 3     2013 3     2    1    14    17  21   36  400 50  ⋯  8.125000
# 4     2013 3     2    2    13    13  20   37  400 47  ⋯  8.375000
# 5     2013 3     2    3     3     9  13   34  400 52  ⋯  8.250000
# 6     2013 3     2    4     3     7  18   43  400 43  ⋯  8.250000
# 7     2013 3     2    5     9    11  19   70  500 20  ⋯  8.416667
# 8     2013 3     2    6     4    10  28   46  500 39  ⋯  8.458333
# 9     2013 3     2    7     3    11  34   58  500 27  ⋯  8.458333
# 10    2013 3     2    8     3     7  21   49  500 43  ⋯  8.458333
# 11    2013 3     2    9    10    14  47   62  700 29  ⋯  8.750000
# 12    2013 3     2   10    11    19  36   60  600 34  ⋯  9.083333
# 13    2013 3     2   11    18    29  36   70  800 27  ⋯  9.708333
# 14    2013 3     2   12    26    30  25   76  900 22  ⋯ 10.666667
# 15    2013 3     2   13    25    33  20   57  700 39  ⋯ 11.583333
# 16    2013 3     2   14    26    35  22   54  700 43  ⋯ 12.416667
# 17    2013 3     2   15    37    40  24   55  700 44  ⋯ 13.625000
# 18    2013 3     2   16    37    46  29   63 1000 38  ⋯ 14.791667
# 19    2013 3     2   17    44    58  45   77 1200 30  ⋯ 16.208333
# 20    2013 3     2   18    54    79  50   80 1100 24  ⋯ 18.000000
# 21    2013 3     2   19    61    86  50   97 1300 10  ⋯ 20.208333
# 22    2013 3     2   20    67    96  54  108 1399  2  ⋯ 22.541667
# 23    2013 3     2   21    74   103  72  107 1399  2  ⋯ 25.125000
# 24    2013 3     2   22    81   113  84  110 1500  3  ⋯ 27.875000
# 25    2013 3     2   23    93   120  87  107 1700  2  ⋯ 30.750000
# 26    2013 3     3    0   112   130  73  100 1899  2  ⋯ 34.500000
# 27    2013 3     3    1   109   132  80  101 2200  2  ⋯ 38.458333
# 28    2013 3     3    2   110   132  98   99 2399  2  ⋯ 42.500000
# 29    2013 3     3    3   105   129  88  100 2500  2  ⋯ 46.750000
# 30    2013 3     3    4   106   136  79   92 2799  2  ⋯ 51.041667
# ⋮     ⋮    ⋮     ⋮   ⋮    ⋮     ⋮    ⋮   ⋮   ⋮    ⋮   ⋱ ⋮
# 31763 2017 2     27  18   47     60   9   53  700 106 ⋯ 61.16667
# 31764 2017 2     27  19   51     77  10   90  100  62 ⋯ 62.20833
# 31765 2017 2     27  20   51     77   9  116 1100  35 ⋯ 63.12500
# 31766 2017 2     27  21   53     82   9  124 1200  24 ⋯ 64.08333
# 31767 2017 2     27  22   58    106  17  133 1500  19 ⋯ 65.25000
# 31768 2017 2     27  23   70    107  28  131 1700  19 ⋯ 66.66667
# 31769 2017 2     28   0   56     56  22  119 1400  18 ⋯ 67.25000
# 31770 2017 2     28   1   15     15   7   45  500  71 ⋯ 65.75000
# 31771 2017 2     28   2    9     16   7   33  400  82 ⋯ 64.20833
# 31772 2017 2     28   3    7     15   8   42  300  70 ⋯ 62.91667
# 31773 2017 2     28   4   13     21  14   45  500  66 ⋯ 61.16667
# 31774 2017 2     28   5   12     22  16   29  400  77 ⋯ 58.45833
# 31775 2017 2     28   6    9     16  17   34  500  73 ⋯ 55.29167
# 31776 2017 2     28   7   11     24  15   47  500  61 ⋯ 51.83333
# 31777 2017 2     28   8   13     33  16   52  500  58 ⋯ 48.37500
# 31778 2017 2     28   9   12     24  13   46  500  69 ⋯ 45.54167
# 31779 2017 2     28  10   11     16   6   24  300  93 ⋯ 42.95833
# 31780 2017 2     28  11    7      8   4   12  200 107 ⋯ 40.70833
# 31781 2017 2     28  12    6     13   3   10  200 112 ⋯ 38.79167
# 31782 2017 2     28  13    6      8   3    9  100 115 ⋯ 35.33333
# 31783 2017 2     28  14    5      5   4    8  100 117 ⋯ 31.25000
# 31784 2017 2     28  15    6     19   4    8  100 122 ⋯ 27.54167
# 31785 2017 2     28  16   12     18   5    9  200 122 ⋯ 24.91667
# 31786 2017 2     28  17   12     23   6   13  200 120 ⋯ 23.00000
# 31787 2017 2     28  18   13     29   5   22  300 109 ⋯ 21.58333
# 31788 2017 2     28  19   12     29   5   35  400  95 ⋯ 19.95833
# 31789 2017 2     28  20   13     37   7   45  500  81 ⋯ 18.37500
# 31790 2017 2     28  21   16     37  10   66  700  58 ⋯ 16.83333
# 31791 2017 2     28  22   21     44  12   87  700  35 ⋯ 15.29167
# 31792 2017 2     28  23   19     31  10   79  600  42 ⋯ 13.16667
#       pm10_24hour co_8hour  o3_8hour     pm2.5_aqi pm10_aqi so2_aqi no2_aqi
# 1     10.75000    0.4168641 0.0263273591  30       10       13      25
# 2     11.58333    0.4255614 0.0243705119  33       11       12      20
# 3     11.95833    0.4246043 0.0228959608  34       12       11      17
# 4     12.20833    0.4138305 0.0215023218  35       12       10      17
# 5     12.33333    0.4032704 0.0209912119  35       12        7      16
# 6     12.50000    0.3829259 0.0202643194  35       12        9      20
# 7     12.75000    0.3824938 0.0185281120  36       12       10      32
# 8     13.04167    0.3621904 0.0189052425  36       13       14      21
# 9     13.25000    0.3521262 0.0183816590  36       13       17      27
# 10    13.29167    0.3521930 0.0183277308  36       13       11      23
# 11    13.54167    0.3820760 0.0171402341  37       13       24      29
# 12    14.08333    0.4024358 0.0164252223  38       14       18      28
# 13    15.04167    0.4427906 0.0150220502  41       14       18      32
# 14    16.04167    0.4933441 0.0138475943  45       15       13      35
# 15    17.16667    0.5144759 0.0149827399  49       16       10      27
# 16    18.25000    0.5358983 0.0152790790  52       17       12      25
# 17    19.29167    0.5572594 0.0163153392  55       18       13      26
# 18    20.41667    0.6083928 0.0160726804  57       19       15      30
# 19    21.87500    0.6591367 0.0161510231  60       21       23      36
# 20    24.33333    0.7091005 0.0155778581  64       23       25      37
# 21    27.33333    0.7591196 0.0145937120  69       26       25      45
# 22    30.62500    0.8086721 0.0134308438  73       29       27      50
# 23    34.16667    0.8776258 0.0112709568  79       32       36      49
# 24    38.08333    0.9558135 0.0089281567  85       36       42      50
# 25    42.08333    1.0537854 0.0064664847  91       39       44      49
# 26    46.50000    1.1411491 0.0043581965  99       44       37      46
# 27    51.29167    1.2384742 0.0027258009 109       48       40      46
# 28    56.25000    1.3653549 0.0014475085 119       52       49      45
# 29    61.25000    1.4825572 0.0009813526 129       55       44      46
# 30    66.62500    1.6179015 0.0009796962 140       57       39      42
# ⋮     ⋮           ⋮         ⋮            ⋮         ⋮        ⋮       ⋮
# 31763 81.16667    0.8616492 0.03383586   154       64        5      26
# 31764 82.79167    0.8520225 0.03731135   155       65        6      44
# 31765 84.25000    0.8457376 0.03814601   155       66        5      57
# 31766 85.83333    0.7878710 0.03806530   156       67        5      61
# 31767 88.29167    0.7450380 0.03450326   157       68        9      66
# 31768 90.58333    0.7523601 0.03028864   157       69       15      65
# 31769 90.20833    0.8865506 0.02452417   158       69       12      58
# 31770 87.41667    0.8534832 0.02151296   157       68        4      22
# 31771 85.50000    0.8211281 0.01994049   156       67        4      16
# 31772 83.16667    0.8414443 0.02035690   155       65        5      20
# 31773 79.87500    0.7779817 0.02216897   154       64        8      22
# 31774 76.12500    0.6931036 0.02527304   153       62        9      14
# 31775 71.87500    0.5879205 0.02851145   150       60        9      17
# 31776 67.41667    0.4629093 0.03102006   142       58        8      23
# 31777 64.79167    0.3696663 0.03342161   133       56        9      25
# 31778 62.08333    0.3700455 0.03333214   126       55        7      22
# 31779 59.37500    0.3601105 0.03405661   120       54        4      12
# 31780 56.37500    0.3503011 0.03640382   114       52        3       6
# 31781 54.33333    0.3200527 0.03929482   110       51        2       5
# 31782 48.41667    0.2898764 0.04177275   100       45        2       5
# 31783 43.33333    0.2487983 0.04456878    92       41        3       4
# 31784 40.00000    0.2079686 0.04843353    84       38        3       4
# 31785 37.62500    0.1775533 0.05245966    78       35        3       5
# 31786 35.87500    0.1468203 0.05566230    74       34        4       7
# 31787 34.58333    0.1470850 0.05669009    71       33        3      11
# 31788 32.58333    0.1679922 0.05595566    68       31        3      17
# 31789 30.91667    0.1992035 0.05405118    65       29        4      22
# 31790 29.04167    0.2614157 0.05051958    61       27        6      32
# 31791 26.45833    0.3235023 0.04544510    58       25        7      42
# 31792 23.29167    0.3747832 0.04044762    54       22        6      38
#       co_aqi o3_aqi
# 1      5     25
# 2      5     23
# 3      5     22
# 4      5     20
# 5      5     20
# 6      5     19
# 7      5     18
# 8      5     18
# 9      5     18
# 10     5     17
# 11     5     16
# 12     5     16
# 13     6     14
# 14     6     13
# 15     6     14
# 16     7     15
# 17     7     16
# 18     7     15
# 19     8     15
# 20     9     15
# 21     9     14
# 22    10     13
# 23    10     11
# 24    11      9
# 25    12      6
# 26    13      5
# 27    15      3
# 28    16      2
# 29    17      1
# 30    19      1
# ⋮     ⋮      ⋮
# 31763 10     32
# 31764 10     35
# 31765 10     36
# 31766  9     36
# 31767  9     32
# 31768  9     29
# 31769 11     23
# 31770 10     20
# 31771 10     19
# 31772 10     19
# 31773  9     21
# 31774  8     24
# 31775  7     27
# 31776  6     29
# 31777  5     31
# 31778  5     31
# 31779  5     32
# 31780  4     34
# 31781  4     37
# 31782  4     39
# 31783  3     42
# 31784  3     45
# 31785  3     49
# 31786  2     54
# 31787  2     57
# 31788  2     55
# 31789  3     48
# 31790  3     47
# 31791  4     43
# 31792  5     38

# %%
air_quality_data <- air_quality_data |>
    select(year, month, day, hour, TEMP, PRES, DEWP, RAIN, WSPM, pm2.5_aqi, pm10_aqi, so2_aqi, no2_aqi, co_aqi, o3_aqi) |>
    group_by(year, month, day) |>
    summarize(across(TEMP:WSPM, mean), across(pm2.5_aqi:o3_aqi, max)) |>
    rowwise()|>
    mutate(aqi = round(max(pm2.5_aqi:o3_aqi)))
head(air_quality_data, 3)
tail(air_quality_data, 3)
# Out:
# `summarise()` has grouped output by 'year', 'month'. You can override using the
# `.groups` argument.
#   year month day TEMP       PRES     DEWP      RAIN WSPM     pm2.5_aqi pm10_aqi
# 1 2013 3     1   -0.2000000 1030.500 -17.40000 0    1.400000  30       10
# 2 2013 3     2    0.6166667 1026.850 -15.93750 0    1.479167  91       39
# 3 2013 3     3    5.5666667 1014.608 -12.31667 0    1.658333 166       85
#   so2_aqi no2_aqi co_aqi o3_aqi aqi
# 1 13      25       5     25      30
# 2 44      50      12     23      91
# 3 66      67      22     24     166
#   year month day TEMP      PRES     DEWP       RAIN WSPM     pm2.5_aqi pm10_aqi
# 1 2017 2     26   7.208333 1020.337  -8.258333 0    1.566667  85       38
# 2 2017 2     27   7.809524 1017.143  -7.395238 0    1.523810 157       69
# 3 2017 2     28  10.958333 1014.888 -12.783333 0    2.058333 158       69
#   so2_aqi no2_aqi co_aqi o3_aqi aqi
# 1 10      48      10     39      85
# 2 21      66      17     36     157
# 3 12      58      11     57     158

# %%
air_quality_data_split <- initial_split(air_quality_data, prop = 0.75, strata = aqi)
aqd_train <- training(air_quality_data_split)
aqd_test <- testing(air_quality_data_split)

# %%
aqd_spec <- linear_reg() |>
    set_engine("lm") |>
    set_mode("regression")
aqd_recipe <- recipe(co_aqi ~ TEMP + PRES + DEWP + RAIN + WSPM, data = aqd_train) |>
    step_scale(all_predictors()) |>
    step_center(all_predictors())

# %%
aqd_results <- workflow() |>
    add_recipe(aqd_recipe) |>
    add_model(aqd_spec) |>
    fit(aqd_train) |>
    predict(aqd_train) |>
    bind_cols(aqd_train) |>
    metrics(truth = co_aqi, estimate = .pred)
aqd_results
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   10.6141883
# 2 rsq     standard    0.3339546
# 3 mae     standard    7.5346760

# %%
aqd_vfold <- vfold_cv(data = aqd_train, v = 5, strata = aqi)
aqd_workflow <- workflow() |>
    add_recipe(aqd_recipe) |>
    add_model(aqd_spec)

# %%
gridvals <- tibble(neighbors = 1:10)
aqd_results <- tune_grid(aqd_workflow, resamples = aqd_vfold, grid = gridvals) |>
    collect_metrics()
aqd_results
# Out:
#     neighbors .metric .estimator mean        n std_err
# 1    1        rmse    standard   84.79752130 5 2.19028745
# 2    1        rsq     standard    0.09037377 5 0.01401985
# 3    2        rmse    standard   73.74079248 5 1.40331002
# 4    2        rsq     standard    0.11619471 5 0.01281299
# 5    3        rmse    standard   68.12994383 5 1.12215408
# 6    3        rsq     standard    0.16265399 5 0.01660734
# 7    4        rmse    standard   66.23361069 5 0.81807367
# 8    4        rsq     standard    0.17391364 5 0.01930675
# 9    5        rmse    standard   64.86948363 5 1.20547611
# 10   5        rsq     standard    0.19418967 5 0.02956506
# 11   6        rmse    standard   64.21102960 5 1.28147226
# 12   6        rsq     standard    0.19843760 5 0.02750903
# 13   7        rmse    standard   63.40730874 5 1.28420182
# 14   7        rsq     standard    0.20758524 5 0.02781455
# 15   8        rmse    standard   62.79885870 5 1.05334005
# 16   8        rsq     standard    0.21613944 5 0.02411084
# 17   9        rmse    standard   62.74115252 5 1.08875027
# 18   9        rsq     standard    0.21465644 5 0.01871908
# 19  10        rmse    standard   62.46472043 5 1.25297333
# 20  10        rsq     standard    0.21956981 5 0.01963375
# 21  11        rmse    standard   62.34615449 5 1.42243941
# 22  11        rsq     standard    0.22126690 5 0.01992046
# 23  12        rmse    standard   62.17899423 5 1.46461143
# 24  12        rsq     standard    0.22424775 5 0.01959753
# 25  13        rmse    standard   61.99486949 5 1.45106276
# 26  13        rsq     standard    0.22711652 5 0.01796901
# 27  14        rmse    standard   62.08673300 5 1.45172241
# 28  14        rsq     standard    0.22413460 5 0.01910767
# 29  15        rmse    standard   62.00014862 5 1.29079463
# 30  15        rsq     standard    0.22565491 5 0.01823827
# ⋮   ⋮         ⋮       ⋮          ⋮           ⋮ ⋮
# 171  86       rmse    standard   65.4231746  5 1.08170662
# 172  86       rsq     standard    0.1461523  5 0.01141590
# 173  87       rmse    standard   65.4460333  5 1.10143516
# 174  87       rsq     standard    0.1458666  5 0.01123573
# 175  88       rmse    standard   65.4492610  5 1.10085165
# 176  88       rsq     standard    0.1460378  5 0.01114416
# 177  89       rmse    standard   65.5213562  5 1.11553579
# 178  89       rsq     standard    0.1439244  5 0.01154528
# 179  90       rmse    standard   65.5413857  5 1.12757180
# 180  90       rsq     standard    0.1436614  5 0.01150715
# 181  91       rmse    standard   65.5833491  5 1.14891532
# 182  91       rsq     standard    0.1426911  5 0.01187522
# 183  92       rmse    standard   65.6050130  5 1.14486962
# 184  92       rsq     standard    0.1420707  5 0.01167899
# 185  93       rmse    standard   65.6377555  5 1.14815117
# 186  93       rsq     standard    0.1412178  5 0.01182786
# 187  94       rmse    standard   65.7056590  5 1.14542739
# 188  94       rsq     standard    0.1393011  5 0.01192985
# 189  95       rmse    standard   65.7683745  5 1.13990699
# 190  95       rsq     standard    0.1372556  5 0.01189239
# 191  96       rmse    standard   65.7964532  5 1.15316363
# 192  96       rsq     standard    0.1366060  5 0.01240535
# 193  97       rmse    standard   65.8246553  5 1.15093901
# 194  97       rsq     standard    0.1357117  5 0.01192163
# 195  98       rmse    standard   65.8946769  5 1.14055675
# 196  98       rsq     standard    0.1335587  5 0.01176905
# 197  99       rmse    standard   65.9265300  5 1.14425905
# 198  99       rsq     standard    0.1329478  5 0.01232962
# 199 100       rmse    standard   65.9511587  5 1.13117352
# 200 100       rsq     standard    0.1323578  5 0.01280908
#     .config
# 1   Preprocessor1_Model001
# 2   Preprocessor1_Model001
# 3   Preprocessor1_Model002
# 4   Preprocessor1_Model002
# 5   Preprocessor1_Model003
# 6   Preprocessor1_Model003
# 7   Preprocessor1_Model004
# 8   Preprocessor1_Model004
# 9   Preprocessor1_Model005
# 10  Preprocessor1_Model005
# 11  Preprocessor1_Model006
# 12  Preprocessor1_Model006
# 13  Preprocessor1_Model007
# 14  Preprocessor1_Model007
# 15  Preprocessor1_Model008
# 16  Preprocessor1_Model008
# 17  Preprocessor1_Model009
# 18  Preprocessor1_Model009
# 19  Preprocessor1_Model010
# 20  Preprocessor1_Model010
# 21  Preprocessor1_Model011
# 22  Preprocessor1_Model011
# 23  Preprocessor1_Model012
# 24  Preprocessor1_Model012
# 25  Preprocessor1_Model013
# 26  Preprocessor1_Model013
# 27  Preprocessor1_Model014
# 28  Preprocessor1_Model014
# 29  Preprocessor1_Model015
# 30  Preprocessor1_Model015
# ⋮   ⋮
# 171 Preprocessor1_Model086
# 172 Preprocessor1_Model086
# 173 Preprocessor1_Model087
# 174 Preprocessor1_Model087
# 175 Preprocessor1_Model088
# 176 Preprocessor1_Model088
# 177 Preprocessor1_Model089
# 178 Preprocessor1_Model089
# 179 Preprocessor1_Model090
# 180 Preprocessor1_Model090
# 181 Preprocessor1_Model091
# 182 Preprocessor1_Model091
# 183 Preprocessor1_Model092
# 184 Preprocessor1_Model092
# 185 Preprocessor1_Model093
# 186 Preprocessor1_Model093
# 187 Preprocessor1_Model094
# 188 Preprocessor1_Model094
# 189 Preprocessor1_Model095
# 190 Preprocessor1_Model095
# 191 Preprocessor1_Model096
# 192 Preprocessor1_Model096
# 193 Preprocessor1_Model097
# 194 Preprocessor1_Model097
# 195 Preprocessor1_Model098
# 196 Preprocessor1_Model098
# 197 Preprocessor1_Model099
# 198 Preprocessor1_Model099
# 199 Preprocessor1_Model100
# 200 Preprocessor1_Model100

# %%
aqd_results |>
    filter(.metric == "rmse") |>
    arrange(by = mean)
aqd_results
# Out:
#     neighbors .metric .estimator mean     n std_err   .config
# 1   18        rmse    standard   61.81579 5 1.440105  Preprocessor1_Model018
# 2   17        rmse    standard   61.82326 5 1.414631  Preprocessor1_Model017
# 3   16        rmse    standard   61.93849 5 1.424480  Preprocessor1_Model016
# 4   13        rmse    standard   61.99487 5 1.451063  Preprocessor1_Model013
# 5   15        rmse    standard   62.00015 5 1.290795  Preprocessor1_Model015
# 6   19        rmse    standard   62.07878 5 1.405028  Preprocessor1_Model019
# 7   14        rmse    standard   62.08673 5 1.451722  Preprocessor1_Model014
# 8   12        rmse    standard   62.17899 5 1.464611  Preprocessor1_Model012
# 9   20        rmse    standard   62.30800 5 1.279892  Preprocessor1_Model020
# 10  11        rmse    standard   62.34615 5 1.422439  Preprocessor1_Model011
# 11  21        rmse    standard   62.40754 5 1.249846  Preprocessor1_Model021
# 12  10        rmse    standard   62.46472 5 1.252973  Preprocessor1_Model010
# 13  23        rmse    standard   62.62054 5 1.292859  Preprocessor1_Model023
# 14  22        rmse    standard   62.63437 5 1.183320  Preprocessor1_Model022
# 15  24        rmse    standard   62.71941 5 1.272676  Preprocessor1_Model024
# 16   9        rmse    standard   62.74115 5 1.088750  Preprocessor1_Model009
# 17  28        rmse    standard   62.76688 5 1.207305  Preprocessor1_Model028
# 18  27        rmse    standard   62.77317 5 1.210319  Preprocessor1_Model027
# 19  26        rmse    standard   62.79627 5 1.216476  Preprocessor1_Model026
# 20   8        rmse    standard   62.79886 5 1.053340  Preprocessor1_Model008
# 21  25        rmse    standard   62.85288 5 1.223946  Preprocessor1_Model025
# 22  29        rmse    standard   62.95506 5 1.074459  Preprocessor1_Model029
# 23  30        rmse    standard   63.11325 5 1.108704  Preprocessor1_Model030
# 24  32        rmse    standard   63.22090 5 1.167706  Preprocessor1_Model032
# 25  31        rmse    standard   63.22967 5 1.154615  Preprocessor1_Model031
# 26  33        rmse    standard   63.36546 5 1.188601  Preprocessor1_Model033
# 27   7        rmse    standard   63.40731 5 1.284202  Preprocessor1_Model007
# 28  34        rmse    standard   63.50986 5 1.188514  Preprocessor1_Model034
# 29  37        rmse    standard   63.67556 5 1.230681  Preprocessor1_Model037
# 30  35        rmse    standard   63.68486 5 1.210818  Preprocessor1_Model035
# ⋮   ⋮         ⋮       ⋮          ⋮        ⋮ ⋮         ⋮
# 71   75       rmse    standard   64.88469 5 1.1330572 Preprocessor1_Model075
# 72   76       rmse    standard   64.91432 5 1.0946680 Preprocessor1_Model076
# 73   77       rmse    standard   65.01748 5 1.0714039 Preprocessor1_Model077
# 74   78       rmse    standard   65.06738 5 1.0460139 Preprocessor1_Model078
# 75   79       rmse    standard   65.14792 5 1.0566037 Preprocessor1_Model079
# 76   80       rmse    standard   65.17760 5 1.0653000 Preprocessor1_Model080
# 77   81       rmse    standard   65.24820 5 1.0920006 Preprocessor1_Model081
# 78   83       rmse    standard   65.33638 5 1.0691560 Preprocessor1_Model083
# 79   82       rmse    standard   65.35068 5 1.0782609 Preprocessor1_Model082
# 80   84       rmse    standard   65.39026 5 1.0893207 Preprocessor1_Model084
# 81   85       rmse    standard   65.41044 5 1.0824019 Preprocessor1_Model085
# 82   86       rmse    standard   65.42317 5 1.0817066 Preprocessor1_Model086
# 83   87       rmse    standard   65.44603 5 1.1014352 Preprocessor1_Model087
# 84   88       rmse    standard   65.44926 5 1.1008516 Preprocessor1_Model088
# 85   89       rmse    standard   65.52136 5 1.1155358 Preprocessor1_Model089
# 86   90       rmse    standard   65.54139 5 1.1275718 Preprocessor1_Model090
# 87   91       rmse    standard   65.58335 5 1.1489153 Preprocessor1_Model091
# 88   92       rmse    standard   65.60501 5 1.1448696 Preprocessor1_Model092
# 89   93       rmse    standard   65.63776 5 1.1481512 Preprocessor1_Model093
# 90   94       rmse    standard   65.70566 5 1.1454274 Preprocessor1_Model094
# 91   95       rmse    standard   65.76837 5 1.1399070 Preprocessor1_Model095
# 92   96       rmse    standard   65.79645 5 1.1531636 Preprocessor1_Model096
# 93   97       rmse    standard   65.82466 5 1.1509390 Preprocessor1_Model097
# 94   98       rmse    standard   65.89468 5 1.1405567 Preprocessor1_Model098
# 95   99       rmse    standard   65.92653 5 1.1442590 Preprocessor1_Model099
# 96  100       rmse    standard   65.95116 5 1.1311735 Preprocessor1_Model100
# 97    4       rmse    standard   66.23361 5 0.8180737 Preprocessor1_Model004
# 98    3       rmse    standard   68.12994 5 1.1221541 Preprocessor1_Model003
# 99    2       rmse    standard   73.74079 5 1.4033100 Preprocessor1_Model002
# 100   1       rmse    standard   84.79752 5 2.1902875 Preprocessor1_Model001
#     neighbors .metric .estimator mean        n std_err
# 1    1        rmse    standard   84.79752130 5 2.19028745
# 2    1        rsq     standard    0.09037377 5 0.01401985
# 3    2        rmse    standard   73.74079248 5 1.40331002
# 4    2        rsq     standard    0.11619471 5 0.01281299
# 5    3        rmse    standard   68.12994383 5 1.12215408
# 6    3        rsq     standard    0.16265399 5 0.01660734
# 7    4        rmse    standard   66.23361069 5 0.81807367
# 8    4        rsq     standard    0.17391364 5 0.01930675
# 9    5        rmse    standard   64.86948363 5 1.20547611
# 10   5        rsq     standard    0.19418967 5 0.02956506
# 11   6        rmse    standard   64.21102960 5 1.28147226
# 12   6        rsq     standard    0.19843760 5 0.02750903
# 13   7        rmse    standard   63.40730874 5 1.28420182
# 14   7        rsq     standard    0.20758524 5 0.02781455
# 15   8        rmse    standard   62.79885870 5 1.05334005
# 16   8        rsq     standard    0.21613944 5 0.02411084
# 17   9        rmse    standard   62.74115252 5 1.08875027
# 18   9        rsq     standard    0.21465644 5 0.01871908
# 19  10        rmse    standard   62.46472043 5 1.25297333
# 20  10        rsq     standard    0.21956981 5 0.01963375
# 21  11        rmse    standard   62.34615449 5 1.42243941
# 22  11        rsq     standard    0.22126690 5 0.01992046
# 23  12        rmse    standard   62.17899423 5 1.46461143
# 24  12        rsq     standard    0.22424775 5 0.01959753
# 25  13        rmse    standard   61.99486949 5 1.45106276
# 26  13        rsq     standard    0.22711652 5 0.01796901
# 27  14        rmse    standard   62.08673300 5 1.45172241
# 28  14        rsq     standard    0.22413460 5 0.01910767
# 29  15        rmse    standard   62.00014862 5 1.29079463
# 30  15        rsq     standard    0.22565491 5 0.01823827
# ⋮   ⋮         ⋮       ⋮          ⋮           ⋮ ⋮
# 171  86       rmse    standard   65.4231746  5 1.08170662
# 172  86       rsq     standard    0.1461523  5 0.01141590
# 173  87       rmse    standard   65.4460333  5 1.10143516
# 174  87       rsq     standard    0.1458666  5 0.01123573
# 175  88       rmse    standard   65.4492610  5 1.10085165
# 176  88       rsq     standard    0.1460378  5 0.01114416
# 177  89       rmse    standard   65.5213562  5 1.11553579
# 178  89       rsq     standard    0.1439244  5 0.01154528
# 179  90       rmse    standard   65.5413857  5 1.12757180
# 180  90       rsq     standard    0.1436614  5 0.01150715
# 181  91       rmse    standard   65.5833491  5 1.14891532
# 182  91       rsq     standard    0.1426911  5 0.01187522
# 183  92       rmse    standard   65.6050130  5 1.14486962
# 184  92       rsq     standard    0.1420707  5 0.01167899
# 185  93       rmse    standard   65.6377555  5 1.14815117
# 186  93       rsq     standard    0.1412178  5 0.01182786
# 187  94       rmse    standard   65.7056590  5 1.14542739
# 188  94       rsq     standard    0.1393011  5 0.01192985
# 189  95       rmse    standard   65.7683745  5 1.13990699
# 190  95       rsq     standard    0.1372556  5 0.01189239
# 191  96       rmse    standard   65.7964532  5 1.15316363
# 192  96       rsq     standard    0.1366060  5 0.01240535
# 193  97       rmse    standard   65.8246553  5 1.15093901
# 194  97       rsq     standard    0.1357117  5 0.01192163
# 195  98       rmse    standard   65.8946769  5 1.14055675
# 196  98       rsq     standard    0.1335587  5 0.01176905
# 197  99       rmse    standard   65.9265300  5 1.14425905
# 198  99       rsq     standard    0.1329478  5 0.01232962
# 199 100       rmse    standard   65.9511587  5 1.13117352
# 200 100       rsq     standard    0.1323578  5 0.01280908
#     .config
# 1   Preprocessor1_Model001
# 2   Preprocessor1_Model001
# 3   Preprocessor1_Model002
# 4   Preprocessor1_Model002
# 5   Preprocessor1_Model003
# 6   Preprocessor1_Model003
# 7   Preprocessor1_Model004
# 8   Preprocessor1_Model004
# 9   Preprocessor1_Model005
# 10  Preprocessor1_Model005
# 11  Preprocessor1_Model006
# 12  Preprocessor1_Model006
# 13  Preprocessor1_Model007
# 14  Preprocessor1_Model007
# 15  Preprocessor1_Model008
# 16  Preprocessor1_Model008
# 17  Preprocessor1_Model009
# 18  Preprocessor1_Model009
# 19  Preprocessor1_Model010
# 20  Preprocessor1_Model010
# 21  Preprocessor1_Model011
# 22  Preprocessor1_Model011
# 23  Preprocessor1_Model012
# 24  Preprocessor1_Model012
# 25  Preprocessor1_Model013
# 26  Preprocessor1_Model013
# 27  Preprocessor1_Model014
# 28  Preprocessor1_Model014
# 29  Preprocessor1_Model015
# 30  Preprocessor1_Model015
# ⋮   ⋮
# 171 Preprocessor1_Model086
# 172 Preprocessor1_Model086
# 173 Preprocessor1_Model087
# 174 Preprocessor1_Model087
# 175 Preprocessor1_Model088
# 176 Preprocessor1_Model088
# 177 Preprocessor1_Model089
# 178 Preprocessor1_Model089
# 179 Preprocessor1_Model090
# 180 Preprocessor1_Model090
# 181 Preprocessor1_Model091
# 182 Preprocessor1_Model091
# 183 Preprocessor1_Model092
# 184 Preprocessor1_Model092
# 185 Preprocessor1_Model093
# 186 Preprocessor1_Model093
# 187 Preprocessor1_Model094
# 188 Preprocessor1_Model094
# 189 Preprocessor1_Model095
# 190 Preprocessor1_Model095
# 191 Preprocessor1_Model096
# 192 Preprocessor1_Model096
# 193 Preprocessor1_Model097
# 194 Preprocessor1_Model097
# 195 Preprocessor1_Model098
# 196 Preprocessor1_Model098
# 197 Preprocessor1_Model099
# 198 Preprocessor1_Model099
# 199 Preprocessor1_Model100
# 200 Preprocessor1_Model100
